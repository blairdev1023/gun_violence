# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Load

# %%
df = pd.read_csv('data/gun-violence-data_01-2013_03-2018.csv', index_col='incident_id')
df.head()
# Out:
#                    date           state city_or_county  \
# incident_id
# 461105       2013-01-01    Pennsylvania     Mckeesport
# 460726       2013-01-01      California      Hawthorne
# 478855       2013-01-01            Ohio         Lorain
# 478925       2013-01-05        Colorado         Aurora
# 478959       2013-01-07  North Carolina     Greensboro
#
#                                                address  n_killed  n_injured  \
# incident_id
# 461105       1506 Versailles Avenue and Coursin Street         0          4
# 460726                    13500 block of Cerise Avenue         1          3
# 478855                           1776 East 28th Street         1          3
# 478925                16000 block of East Ithaca Place         4          0
# 478959                       307 Mourning Dove Terrace         2          2
#
#                                                   incident_url  \
# incident_id
# 461105       http://www.gunviolencearchive.org/incident/461105
# ...

# %% [markdown]
# # ETL
# * Drop
#     * source_url
#     * incident_url_fields_missing
#     * congressional_district
#     * gun_stolen
#     * incident_characteristics
#     * n_guns_involved
#     * sources
#     * state_house_district
#     * state_senate_district
# * Dates
#     * datetime
#     * Delete pre-2014 data
# * Clean
#     * gun_type
#     * participant_age
#     * participant_age_group
#     * participant_gender
#     * participant_name
#     * participant_relationship
#     * participant_status
#     * participant_type

# %% [markdown]
# ## Drop

# %%
drop_cols = [
    'source_url',
    'incident_url_fields_missing',
    'congressional_district',
    'gun_stolen',
    'incident_characteristics',
    'n_guns_involved',
    'sources',
    'state_house_district',
    'state_senate_district'
]

df.drop(columns=drop_cols, inplace=True)

# %% [markdown]
# ## Clean

# %%
df['date'] = pd.to_datetime(df['date'])
df = df[df['date'].apply(lambda x: x.year >= 2014)]

# %%
def cleaner(string):
    '''
    Returns a list of cleaned strings; broken down from the input string.
    '''
    if type(string) != str:
        return string
    else: 
        return [word[3:] for word in string.split('||')]

# %%
clean_cols = [
    'gun_type',
    'participant_age',
    'participant_age_group',
    'participant_gender',
    'participant_name',
    'participant_relationship',
    'participant_status',
    'participant_type'
]

for col in clean_cols:
    df[col] = df[col].apply(cleaner, convert_dtype=False)

# %% [markdown]
# # Save

# %%
df.head()
# Out:
#                   date       state city_or_county  \
# incident_id
# 95289       2014-01-01    Michigan       Muskegon
# 92401       2014-01-01  New Jersey         Newark
# 92383       2014-01-01    New York         Queens
# 92142       2014-01-01    New York       Brooklyn
# 95261       2014-01-01    Missouri    Springfield
#
#                                  address  n_killed  n_injured  \
# incident_id
# 95289        300 block of Monroe Avenue          0          0
# 92401                     Central Avenue         0          0
# 92383                       113th Avenue         1          0
# 92142                    St. Johns Place         0          1
# 95261           Beverly Hills and Temple         0          1
#
#                                                  incident_url gun_type  \
# incident_id
# 95289        http://www.gunviolencearchive.org/incident/95289      NaN
# 92401        http://www.gunviolencearchive.org/incident/92401      NaN
# ...

# %%
df.to_csv('data/gun_violence_clean.csv', index=False)
